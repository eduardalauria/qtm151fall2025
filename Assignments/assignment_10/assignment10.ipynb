# %% [markdown]
# # Assignment 10

# %% [markdown]
# ## Submit your .ipynb file to Gradescope by Thursday, December 4th **by 10pm**

# %% [markdown]
# ##### Import necessary libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# 1. Converting long to wide format
#
# <font size = "3">
#
# - Load in the data from "daily.csv". This contains the stock prices for Microsoft and Coca-Cola from 1997-2012.
#
# - We are only interested in 3 columns: "symbol", "date", and "adjusted". Create a new DataFrame which contains only these 3 columns.
#
# - Convert the date column to datetime format. I.e. replace the initial "date" column containing strings with one with datetime64 dtype.
#
# - There are two unique values in the "symbol" column, which are the ticker/stock symbols for each company. They correspond to MSFT = Microsoft, and KO = Coca-Cola.
#
# - Using ``pd.pivot`` create a new DataFrame by converting to wide format. Then reset the index, so that "date" is a proper column. Then display/print the DataFrame. The final DataFrame should look something like this:
#
# |  | date | KO | MSFT |
# | --- | --- | --- | --- |
# | 0 | 1997-01-02 | 12.27 | 6.23 |
# | 1 | 1997-01-03 | 12.56 | 6.46 |
# | 2 | 1997-01-06 | 12.44 | 6.44 |
# | ⋮ | ⋮ | ⋮ | ⋮ |

# %%
# your code here
data = pd.read_csv("data/daily.csv")
data_stock = data[['symbol','date','adjusted']]
data_stock['date'] = pd.to_datetime(data_stock["date"])
df_wide = data_stock.pivot(index='date', columns='symbol', values='adjusted')
df_wide = df_wide.reset_index()
df_wide
# Out:
# /var/folders/wq/0vvx7w294snf1ygwtqkx1p6w0000gn/T/ipykernel_72106/1708340509.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_stock['date'] = pd.to_datetime(data_stock["date"])
# symbol       date         KO       MSFT
# 0      1997-01-02  12.272199   6.232640
# 1      1997-01-03  12.567904   6.461713
# 2      1997-01-06  12.449619   6.442623
# 3      1997-01-07  12.863628   6.490343
# 4      1997-01-08  12.627052   6.366264
# ...           ...        ...        ...
# 4020   2012-12-21  24.779921  22.105970
# 4021   2012-12-24  24.672443  21.791899
# 4022   2012-12-26  24.464212  21.630840
# 4023   2012-12-27  24.464212  21.711372
# 4024   2012-12-28  24.161942  21.381184
#
# [4025 rows x 3 columns]

# %% [markdown]
# <font size = "5">
#
# 2. Grouping by time
#
# <font size = "3">
#
# - Continue using the DataFrame in wide format you created in Problem 1.
#
# - Use ``pd.Grouper`` to create a ``TimeGrouper`` object, which will allow you to group the "date" column by **weeks**
#
# - Group the date column by weeks and aggregate the weekly average values for both Coca-Cola and Microsoft.
#
# - On a single figure, plot date vs. adjusted price for both companies. Label the axes and add a figure to the plot. In addition, your plot should contain a legend with two items: "Coca-Cola" and "Microsoft". The legend should have these names exactly as written. The order in which they appear doesn't matter, as long as they correspond to the correct line.

# %%
# your answer here

weekly = df_wide.groupby(pd.Grouper(key='date', freq='W')).mean()

plt.plot(weekly.index, weekly['KO'], label='Coca-Cola')
plt.plot(weekly.index, weekly['MSFT'], label='Microsoft')

# Labels and title
plt.xlabel("Date")
plt.ylabel("Adjusted Price")
plt.title("Weekly Average Adjusted Prices: Coca-Cola vs Microsoft")
plt.legend(['Coca-Cola', 'Microsoft'])

plt.show()

# %% [markdown]
# <font size = "5">
#
# 3. Converting wide to long format
#
# <font size = "3">
#
# - Use ``pd.melt`` to convert the DataFrame you created in Problem 1 back to long format.
#
# - The variable name column should be "ticker_symbol", while the value name column should be "adjusted_price".
#
# - Use ``.set_index`` to make "date" the index column.
#
# - Display/print the DataFrame. The final DataFrame should look something like this:
#
# | date | ticker_symbol | adjusted_price |
# | --- | --- | --- |
# | 1997-01-02 | KO/MSFT | (price value) |
# | 1997-01-03 | KO/MSFT | (price value) |
# | 1997-01-06 | KO/MSFT | (price value) |
# | ⋮ | ⋮ | ⋮ |
#
# - (The exact ordering of ticker_symbol and the first 3 price values can vary, depending on the exact ordering of arguments you use in ``pd.melt``)

# %%
# your code here

# Melt from wide → long format
df_long = pd.melt(
    df_wide,
    id_vars='date',             
    value_vars=['KO', 'MSFT'],   
    var_name='ticker_symbol',    
    value_name='adjusted_price' 
)
df_long = df_long.set_index('date')

df_long
# Out:
#            ticker_symbol  adjusted_price
# date
# 1997-01-02            KO       12.272199
# 1997-01-03            KO       12.567904
# 1997-01-06            KO       12.449619
# 1997-01-07            KO       12.863628
# 1997-01-08            KO       12.627052
# ...                  ...             ...
# 2012-12-21          MSFT       22.105970
# 2012-12-24          MSFT       21.791899
# 2012-12-26          MSFT       21.630840
# 2012-12-27          MSFT       21.711372
# 2012-12-28          MSFT       21.381184
#
# [8050 rows x 2 columns]

# %% [markdown]
# <font size = "5">
#
# 4. Search for strings
#
# <font size = "3">
#
# - Load in the from "Datafiniti_Hotel_Reviews.csv" and save it to a DataFrame named ``hotels``
#
# - The "name" column contains the name of each hotel for which a customer review is available. The names are very specific, for example there is "Hampton Inn and Suites Napa" as well as "Hampton Inn Atlanta-Perimeter Center".
#
# - Using ``.str.contains``, create a Boolean Pandas Series where each entry is "True" if the "name" of the hotel contains the string "Hampton Inn".
#
# - Using this Boolean Series, create a new DataFrame called ``hampton`` which contains all rows from the original DataFrame which have the string "Hampton Inn" in the hotel name.

# %%
# your code here

hotels = pd.read_csv("data/Datafiniti_Hotel_Reviews.csv")
hotel_new = hotels["name"].str.contains("Hampton Inn", case=False, na=False)
hampton = hotels[hotel_new]
hampton
# Out:
#                         id             dateAdded           dateUpdated  \
# 9     AVwePiAX_7pvs4fzBSAl  2016-03-23T04:22:41Z  2018-09-10T21:06:09Z
# 10    AVwePiAX_7pvs4fzBSAl  2016-03-23T04:22:41Z  2018-09-10T21:06:09Z
# 11    AVwePiAX_7pvs4fzBSAl  2016-03-23T04:22:41Z  2018-09-10T21:06:09Z
# 12    AVwePiAX_7pvs4fzBSAl  2016-03-23T04:22:41Z  2018-09-10T21:06:09Z
# 13    AVwePiAX_7pvs4fzBSAl  2016-03-23T04:22:41Z  2018-09-10T21:06:09Z
# ...                    ...                   ...                   ...
# 9926  AVweKSfvIN2L1WUf2hec  2015-11-06T12:12:56Z  2018-01-03T16:00:56Z
# 9927  AVweKSfvIN2L1WUf2hec  2015-11-06T12:12:56Z  2018-01-03T16:00:56Z
# 9928  AVweKSfvIN2L1WUf2hec  2015-11-06T12:12:56Z  2018-01-03T16:00:56Z
# 9929  AVweKSfvIN2L1WUf2hec  2015-11-06T12:12:56Z  2018-01-03T16:00:56Z
# 9930  AVweKSfvIN2L1WUf2hec  2015-11-06T12:12:56Z  2018-01-03T16:00:56Z
#
#                           address  \
# 9               315 SE Olympia Dr
# 10              315 SE Olympia Dr
# 11              315 SE Olympia Dr
# 12              315 SE Olympia Dr
# 13              315 SE Olympia Dr
# ...                           ...
# 9926  31720 Gateway Center Blvd S
# 9927  31720 Gateway Center Blvd S
# 9928  31720 Gateway Center Blvd S
# 9929  31720 Gateway Center Blvd S
# 9930  31720 Gateway Center Blvd S
#
#                                              categories  \
# 9     Hotels,Hotels and motels,Hotel and motel reser...
# 10    Hotels,Hotels and motels,Hotel and motel reser...
# 11    Hotels,Hotels and motels,Hotel and motel reser...
# 12    Hotels,Hotels and motels,Hotel and motel reser...
# 13    Hotels,Hotels and motels,Hotel and motel reser...
# ...                                                 ...
# 9926         Hotels and motels,Hotel,Travel and Tourism
# 9927         Hotels and motels,Hotel,Travel and Tourism
# 9928         Hotels and motels,Hotel,Travel and Tourism
# 9929         Hotels and motels,Hotel,Travel and Tourism
# 9930         Hotels and motels,Hotel,Travel and Tourism
#
#                   primaryCategories         city country  \
# 9     Accommodation & Food Services    Vancouver      US
# 10    Accommodation & Food Services    Vancouver      US
# 11    Accommodation & Food Services    Vancouver      US
# 12    Accommodation & Food Services    Vancouver      US
# 13    Accommodation & Food Services    Vancouver      US
# ...                             ...          ...     ...
# 9926  Accommodation & Food Services  Federal Way      US
# 9927  Accommodation & Food Services  Federal Way      US
# 9928  Accommodation & Food Services  Federal Way      US
# 9929  Accommodation & Food Services  Federal Way      US
# 9930  Accommodation & Food Services  Federal Way      US
#
#                                                    keys   latitude  ...  \
# 9             us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 10            us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 11            us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 12            us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 13            us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# ...                                                 ...        ...  ...
# 9926  us/wa/federalway/31720gatewaycenterblvds/-1473...  47.317158  ...
# 9927  us/wa/federalway/31720gatewaycenterblvds/-1473...  47.317158  ...
# 9928  us/wa/federalway/31720gatewaycenterblvds/-1473...  47.317158  ...
# 9929  us/wa/federalway/31720gatewaycenterblvds/-1473...  47.317158  ...
# 9930  us/wa/federalway/31720gatewaycenterblvds/-1473...  47.317158  ...
#
#                                reviews.dateSeen reviews.rating  \
# 9                          2016-04-19T00:00:00Z            5.0
# 10                         2016-05-13T00:00:00Z            5.0
# 11                         2016-04-19T00:00:00Z            5.0
# 12    2016-03-20T00:00:00Z,2016-04-19T00:00:00Z            5.0
# 13                         2016-07-28T00:00:00Z            5.0
# ...                                         ...            ...
# 9926  2016-04-19T00:00:00Z,2016-03-20T00:00:00Z            5.0
# 9927                       2016-07-28T00:00:00Z            5.0
# 9928  2016-03-20T00:00:00Z,2016-04-19T00:00:00Z            5.0
# 9929                       2016-07-28T00:00:00Z            5.0
# 9930                       2016-04-19T00:00:00Z            5.0
#
#                                      reviews.sourceURLs  \
# 9     https://www.tripadvisor.com/Hotel_Review-g6082...
# 10    https://www.tripadvisor.com/Hotel_Review-g6082...
# 11    https://www.tripadvisor.com/Hotel_Review-g6082...
# 12    http://www.tripadvisor.com/Hotel_Review-g60820...
# 13    https://www.tripadvisor.com/Hotel_Review-g6082...
# ...                                                 ...
# 9926  https://www.tripadvisor.com/Hotel_Review-g5847...
# 9927  https://www.tripadvisor.com/Hotel_Review-g5847...
# 9928  http://www.tripadvisor.com/Hotel_Review-g58471...
# 9929  https://www.tripadvisor.com/Hotel_Review-g5847...
# 9930  https://www.tripadvisor.com/Hotel_Review-g5847...
#
#                                            reviews.text  \
# 9     In my line of work, I use meeting space in hot...
# 10    The staff is very friendly and helpful. The ro...
# 11    Very friendly staff, great free breakfast item...
# 12    Upon arriving I see modern yet elegant decor w...
# 13    This is a nice hotel with great staff. I have ...
# ...                                                 ...
# 9926  If I can I stay here when I come to town. Pric...
# 9927  Great service and food. No complaints they wer...
# 9928  Great property with friendly and helpful staff...
# 9929  The layout of the suite I had was the best roo...
# 9930  I am always pleased with my time at a Hampton ...
#
#                            reviews.title reviews.userCity  \
# 9       Amazing employees and facilities         Portland
# 10                 I loved our stay here              NaN
# 11            Hampton Inn - Vancouver WA          Antioch
# 12                            Perfection         Portland
# 13       Good hotel. Worth checking out.     Port Orchard
# ...                                  ...              ...
# 9926   A great option among area choices        Kennewick
# 9927                        Family visit       Santa Rosa
# 9928  Great Property, Convenient to Area         Ft Worth
# 9929             Best Hampton I've ever!              NaN
# 9930                      Excellent Stay         St. Paul
#
#       reviews.userProvince  reviews.username  \
# 9                      NaN          KristyWM
# 10                     NaN               B M
# 11                     NaN        Cathleen S
# 12                     NaN           1fiesty
# 13                      WA     810michellemm
# ...                    ...               ...
# 9926                    WA            NifT33
# 9927                    CA    N3298TUsimonef
# 9928                   NaN            Rick W
# 9929                   NaN  kimberlybO7908CD
# 9930                   NaN         Douglas J
#
#                                              sourceURLs  \
# 9     https://www.yellowpages.com/vancouver-wa/mip/h...
# 10    https://www.yellowpages.com/vancouver-wa/mip/h...
# 11    https://www.yellowpages.com/vancouver-wa/mip/h...
# 12    https://www.yellowpages.com/vancouver-wa/mip/h...
# 13    https://www.yellowpages.com/vancouver-wa/mip/h...
# ...                                                 ...
# 9926  http://www.yellowbook.com/profile/hampton-inn-...
# 9927  http://www.yellowbook.com/profile/hampton-inn-...
# 9928  http://www.yellowbook.com/profile/hampton-inn-...
# 9929  http://www.yellowbook.com/profile/hampton-inn-...
# 9930  http://www.yellowbook.com/profile/hampton-inn-...
#
#                                                websites
# 9     http://hamptoninn3.hilton.com/en/hotels/washin...
# 10    http://hamptoninn3.hilton.com/en/hotels/washin...
# 11    http://hamptoninn3.hilton.com/en/hotels/washin...
# 12    http://hamptoninn3.hilton.com/en/hotels/washin...
# 13    http://hamptoninn3.hilton.com/en/hotels/washin...
# ...                                                 ...
# 9926                                 http://hampton.com
# 9927                                 http://hampton.com
# 9928                                 http://hampton.com
# 9929                                 http://hampton.com
# 9930                                 http://hampton.com
#
# [691 rows x 25 columns]

# %% [markdown]
# <font size = "5">
#
# 5. Searching with wild cards
#
# <font size = "3">
#
# Use the DataFrame ``hampton`` you created in Problem 4.
#
# The text reviews can be found in the "reviews.text" column of the DataFrame. Use ``str.findall`` to return a Pandas Series with all occurences of strings containing all consecutive characters of any kind immediately followed by the string "nice hotel".
#
# To make this more clear, consider the following string:
#
# - "This was a really nice hotel. Very nice. Love this hotel"
#
# Then the return value of ``str.findall`` should have the sub-string "This was a really nice hotel" as its corresponding element.
#
# Using the ``str.len`` method, create a new Series where all the empty "non-matches" are omitted, leaving only the phrases that matched the search term above.
#
# Repeat this process for the phrase "Nice hotel" with a capital "N". (Again, it should include all consecutive characters before this phrase).
#
# Finally, repeat the process one more time, but in such a way that **both** "nice hotel" and "Nice hotel" are included in the match (again with all consecutive characters preceding them included).
#
# To be clear, your code should create a total of **six** Pandas series, 3 that include empty "non-matches" and 3 where these are excluded.

# %%
# your code here
nice_lower = hampton["reviews.text"].str.findall(r".*nice hotel")
nice_upper = hampton["reviews.text"].str.findall(r".*Nice hotel")
nice_both = hampton["reviews.text"].str.findall(r".*[Nn]ice hotel")

nice_lower_clean = nice_lower[nice_lower.str.len() > 0]
nice_upper_clean = nice_upper[nice_upper.str.len() > 0]
nice_both_clean  = nice_both[nice_both.str.len()  > 0]
